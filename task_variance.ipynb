# %% [markdown]
# **working with the dataset:**
# 4, 8, 6, 5, 3
#
# **Mean**
#
# Mean = 4 + 8 + 6 + 5 + 3 = 26/5 = 5.2
# (4 - 5.2)^2 = (-1.2)^2 = 1.44 (8 - 5.2)^2 = (2.8)^2 = 7.84 (6 - 5.2)^2 = (0.8)^2 = 0.64 (5 - 5.2)^2 = (-0.2)^2 = 0.04 (3 - 5.2)^2 = (-2.2)^2 = 4.84
# 1.44 + 7.84 + 0.64 + 0.04 + 4.84 = 14.8
# (0^2) = 14.8 / 5 = 2.96
